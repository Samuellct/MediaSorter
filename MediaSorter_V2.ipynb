# %% [markdown]
# V2 : added support for end tags, separators (., _) between words, and TV series identification

# %%
#!pip install ipywidgets

# %% [markdown]
# # 1- Imports

# %%
import os
import re
import pandas as pd
import tmdbsimple as tmdb
import time
from collections import defaultdict
from tqdm.notebook import tqdm

# %%
# Common list of end-of-file tags (quality, codec, release group) used to delimit the proper title.
RELEASE_TAGS = [
    r'1080p', r'720p', r'4k', r'2160p', r'bluray', r'webrip', r'webdl', r'hdtv', r'dvdrip', 
    r'x264', r'x265', r'h264', r'h265', r'ac3', r'eac3', r'dts', r'multi', r'truefrench', 
    r'vostfr', r'subfrench', r'fra', r'eng', r'hd', r'bd', r'remux'
]

# %% [markdown]
# # 2- Config

# %%
# ⚠️ Replace with your TMDb API Key
tmdb.API_KEY = 'd1caf3d9d5d31be93bace5476d9ccfd9'  # 'YOUR_TMDB_API_KEY_HERE'

# ⚠️ Replace with the actual path to your media folder
TARGET_FOLDER_PATH = r"E:\Films\#01 converted\newly converted" # r"C:\Your\Media\Folder"

# %%
def clean_name_and_extract_year(name):
    """
    Cleans the file name, extracts year/TV pattern, and isolates the title.
    """
    # 1. Initial cleanup: Remove extension
    name_no_ext = os.path.splitext(name)[0]

    # 2. Check for TV series markers (S01E01, S02, etc.)
    is_tv_pattern = bool(re.search(r'[sS]\d+[eE]\d+|\s[sS]\d+\s', name_no_ext))
    
    # 3. Standardize separators for easier parsing: replace . and _ with spaces
    # We ignore '.' that are part of file extensions before this step (already handled by os.path.splitext)
    working_name = name_no_ext.replace('.', ' ').replace('_', ' ').strip()
    
    year = None
    
    # 4. Extract Year: Search for a 4-digit number that might stand alone or be enclosed in () or []
    year_match = re.search(r'[\s\(](\d{4})[\s\)]?', working_name)
    if year_match:
        year = year_match.group(1)
        # Remove the year from the working name to clean the title
        working_name = working_name.replace(year_match.group(0), ' ').strip()
    
    # 5. Isolate the title: Find the first occurrence of a known release tag or TV tag (S0xE0x)
    
    # Combine TV episode/season pattern with release tags to find the end of the title
    tags_to_find = RELEASE_TAGS + [r'[sS]\d+[eE]\d+', r'[sS]\d+']
    tag_regex = re.compile(r'\b(' + '|'.join(tags_to_find) + r')\b', re.IGNORECASE)
    
    match = tag_regex.search(working_name)
    
    if match:
        # Title is the part of the string before the tag is found
        title_part = working_name[:match.start()].strip()
    else:
        title_part = working_name
    
    # Final cleanup: Remove any remaining excessive spaces or dashes
    cleaned_title = re.sub(r'\s+', ' ', title_part).strip()

    # The title should generally stop if we see "S01E01" (if not already handled)
    if is_tv_pattern:
        tv_match = re.search(r'([sS]\d+[eE]\d+)', cleaned_title)
        if tv_match:
             cleaned_title = cleaned_title[:tv_match.start()].strip()


    # Simple Fallback: if cleaning failed and the title is too long, try just the first few words
    if len(cleaned_title.split()) > 10:
         cleaned_title = ' '.join(cleaned_title.split()[:5])

    return cleaned_title, year, is_tv_pattern

def search_media_info(title, year=None, is_tv_pattern=False):
    """
    Searches TMDb for the title, prioritizing TV search if a pattern is detected.
    """
    if not title:
        return "Invalid Title", None

    director = "Not Specified"
    saga_name = None
    media_type = None
    search = tmdb.Search()

    try:
        if is_tv_pattern:
            # 1. PRIORITY 1a: Search for TV Series
            response = search.tv(query=title)
            media_type = 'tv'
        else:
            # 1. PRIORITY 1b: Search for Movie
            response = search.movie(query=title, year=year)
            media_type = 'movie'

        # 2. PRIORITY 2: Fallback search if the first one yields nothing
        if not response['results']:
            if media_type == 'movie':
                # Fallback from movie to TV
                response = search.tv(query=title)
                media_type = 'tv'
            else:
                # Fallback from TV to movie
                response = search.movie(query=title, year=year)
                media_type = 'movie'

            if not response['results']:
                return "Not Found", None
        
        # 3. Get information from the first result
        result = response['results'][0]
        media_id = result['id']
        
        # Ensure media_type is correctly set based on the final result
        media_type = result.get('media_type', media_type) 

        if media_type == 'movie':
            movie = tmdb.Movies(media_id)
            info = movie.info() 
            credits = movie.credits()

            # Find the Director
            for crew_member in credits.get('crew', []):
                if crew_member.get('job') == 'Director':
                    director = crew_member.get('name')
                    break
            
            # Find the Collection
            collection = info.get('belongs_to_collection')
            if collection:
                saga_name = collection.get('name')
        
        elif media_type == 'tv':
            director = "TV Series"

        return director, saga_name

    except Exception as e:
        # Capture all other errors (API, network issues)
        return f"API Search Error ({type(e).__name__})", None
        
    return "Not Found", None

# %% [markdown]
# ### Fonction principale de scan

# %%
def scan_and_group_media(folder_path):
    
    films_by_director = defaultdict(list)
    films_by_saga = defaultdict(list)
    raw_results = []
    titles_processed = set()

    items_to_analyze = []
    for current_path, sub_folders, files in os.walk(folder_path):
        # We process folder names (usually cleaner) and potential video files
        if current_path == folder_path:
             items_to_analyze.extend(sub_folders)
        
        # Add potential video files
        for f in files:
            if os.path.splitext(f)[1].lower() in ['.mp4', '.mkv', '.avi', '.mov', '.wmv']:
                 items_to_analyze.append(f)

    # tqdm is for the progress bar
    unique_items_to_analyze = list(set(items_to_analyze))

    for name in tqdm(unique_items_to_analyze, desc="🔍 Analyzing Titles and Searching API"):
        
        cleaned_title, year, is_tv_pattern = clean_name_and_extract_year(name)
        
        if cleaned_title and cleaned_title not in titles_processed:
            
            director, saga_name = search_media_info(cleaned_title, year, is_tv_pattern)
            
            # raw results
            raw_results.append({
                'Original Name': name,
                'Cleaned Title': cleaned_title,
                'Year': year if year else '-',
                'Director': director,
                'Saga': saga_name if saga_name else '-',
                'Status': 'OK' # Default status
            })
            
            last_result = raw_results[-1]

            # Setup Manual Check
            if last_result['Director'] == "TV Series":
                last_result['Status'] = 'TV Series'
            elif last_result['Director'] in ["Not Found", "Not Specified"] or "API Search Error" in last_result['Director']:
                last_result['Status'] = 'Manual Check'


            # Grouping Logic (only for identified movies)
            if last_result['Status'] == 'OK':
                films_by_director[director].append(cleaned_title)
                if saga_name:
                    films_by_saga[saga_name].append(cleaned_title)
                
            titles_processed.add(cleaned_title)
            
            time.sleep(0.3) 

    return pd.DataFrame(raw_results), films_by_director, films_by_saga

# %% [markdown]
# ### Main

# %%
if os.path.exists(TARGET_FOLDER_PATH):
    print(f"🎬 Starting scan and online search in: {TARGET_FOLDER_PATH}\n")
    
    df_raw, grouped_by_director, grouped_by_saga = scan_and_group_media(TARGET_FOLDER_PATH)
    
    
    # --- RESULT 4: MANUAL CHECK ---
    print("\n" + "="*70)
    print("❌ RESULT 4: MEDIA REQUIRING MANUAL CHECK")
    print("="*70)

    df_manual = df_raw[df_raw['Status'] == 'Manual Check']
    
    if not df_manual.empty:
        print(f"⚠️ {len(df_manual)} media files require manual verification:")
        display(df_manual[['Original Name', 'Cleaned Title', 'Director', 'Saga', 'Status']])
    else:
        print("No media requires immediate manual verification.")


    # --- RESULT 5: TV SERIES LIST ---
    print("\n" + "="*70)
    print("📺 RESULT 5: TV SERIES IDENTIFIED")
    print("="*70)
    df_tv = df_raw[df_raw['Status'] == 'TV Series']
    if not df_tv.empty:
        # We only display basic titles
        unique_tv_series = df_tv['Cleaned Title'].unique()
        print(f"✅ {len(unique_tv_series)} unique TV series found:")
        print("\n".join([f"    - {title}" for title in unique_tv_series]))
    else:
        print("No TV series found (or identified as TV Series).")
        
    # --- RESULT 1: Grouping by Collection ---
    print("\n" + "="*70)
    print("✅ RESULT 1: GROUPED BY COLLECTION (More than 1 film)")
    print("="*70)
    
    sagas_multiples = {
        saga: films 
        for saga, films in grouped_by_saga.items() 
        if len(films) > 1
    }
    
    if sagas_multiples:
        print(f"📽️  {len(sagas_multiples)} Saga(s) identified:")
        for saga, films in sagas_multiples.items():
            print(f"--- **{saga}** ({len(films)} films) ---")
            for film in sorted(films):
                print(f"    - {film}")
            print("\n")
    else:
        print("No sagas containing more than one film were found.")

    # --- RESULT 2: Grouping by Director (Remaining Unique Films) ---
    print("\n" + "="*70)
    print("✅ RESULT 2: GROUPED BY DIRECTOR (Unique Films)")
    print("="*70)

    directors_multiples = {
        director: films 
        for director, films in grouped_by_director.items() 
        if len(films) > 1
    }

    # Filter out films already grouped by Collection
    films_in_sagas = set()
    for films in sagas_multiples.values():
        films_in_sagas.update(films)

    directors_unique = {}
    for director, films in directors_multiples.items():
        remaining_films = [f for f in films if f not in films_in_sagas]
        if len(remaining_films) > 1:
            directors_unique[director] = remaining_films

    if directors_unique:
        print(f"📽️  {len(directors_unique)} Director(s) with multiple films (excluding sagas above):")
        for director, films in directors_unique.items():
            print(f"--- **{director}** ({len(films)} films) ---")
            for film in sorted(films):
                print(f"    - {film}")
            print("\n")
    else:
        print("No director has directed more than one film not classified in a saga.")
            
    # --- RESULT 3: Display Raw Data ---
    print("\n" + "="*70)
    print("📋 RAW ANALYSIS DETAILS (50 first)")
    print("="*70)
    display(df_raw.head(50))

else:
    print(f"❌ Error: The specified path does not exist: {TARGET_FOLDER_PATH}")
# Out:
# 🎬 Starting scan and online search in: E:\Films\#01 converted\newly converted
# 🔍 Analyzing Titles and Searching API:   0%|          | 0/376 [00:00<?, ?it/s]
# ======================================================================
# ❌ RESULT 4: MEDIA REQUIRING MANUAL CHECK
# ======================================================================
# ⚠️ 6 media files require manual verification:
#                           Original Name            Cleaned Title  \
# 38                            #02 Shows                #02 Shows
# 54           Sauver ou perir (2017).mp4          Sauver ou perir
# 116         Le Chant Du Loup (2018).mp4         Le Chant Du Loup
# 124  Le Proces Goldman (2023) 10bit.mp4  Le Proces Goldman 10bit
# 166             The Covenant (2023).mp4             The Covenant
# 214           The Aviator (2004) v2.mp4           The Aviator v2
#
#           Director Saga        Status
# 38       Not Found    -  Manual Check
# 54       Not Found    -  Manual Check
# 116      Not Found    -  Manual Check
# 124      Not Found    -  Manual Check
# 166  Not Specified    -  Manual Check
# 214      Not Found    -  Manual Check
# ======================================================================
# 📺 RESULT 5: TV SERIES IDENTIFIED
# ======================================================================
# ✅ 7 unique TV series found:
#     - House of the Dragon
#     - Game of Thrones
#     - The Pitt
#     - Wednesday
#     - Game Of Thrones
#     - Euphoria
#     - Stranger Things
#
# ======================================================================
# ✅ RESULT 1: GROUPED BY SAGA/COLLECTION (More than 1 film)
# ======================================================================
# 📽️  7 Saga(s) identified:
# --- **Star Wars Collection** (9 films) ---
#     - Star Wars Episode I The Phantom Menace
#     - Star Wars Episode II Attack Of The Clones
#     - Star Wars Episode III Revenge Of The Sith
#     - Star Wars Episode IV A New Hope
#     - Star Wars Episode Ix The Rise Of Skywalker
#     - Star Wars Episode V The Empire Strikes Back
#     - Star Wars Episode VI Return Of The Jedi
#     - Star Wars Episode VII The Force Awakens
#     - Star Wars Episode Viii The Last Jedi
#
#
# --- **The Incredibles Collection** (2 films) ---
#     - Les Indestructibles
#     - Les Indestructibles 2
#
#
# --- **Cars Collection** (3 films) ---
#     - Cars
#     - Cars 2
#     - Cars 3
#
#
# --- **Mad Max Collection** (3 films) ---
#     - Mad Max
#     - Mad Max 2
#     - Mad Max Beyond Thunderdome
#
#
# --- **Spider-Man: Spider-Verse Collection** (2 films) ---
#     - Spider-Man Across the Spider-Verse
#     - Spider-Man Into The Spider-Verse
#
#
# --- **A Quiet Place Collection** (2 films) ---
#     - A Quiet Place
#     - A Quiet Place Part II
#
#
# --- **Sherlock Holmes Collection** (2 films) ---
#     - Sherlock Holmes
#     - Sherlock Holmes A Game Of Shadows
#
#
#
# ======================================================================
# ✅ RESULT 2: GROUPED BY DIRECTOR (Unique Films)
# ======================================================================
# 📽️  25 Director(s) with multiple films (excluding sagas above):
# --- **Wes Anderson** (8 films) ---
#     - Fantastic Mr Fox
#     - Isle of Dogs
#     - Poison
#     - The French Dispatch
#     - The Phoenician Scheme
#     - The Rat Catcher
#     - The Swan
#     - The Wonderful Story Of Henry Sugar
#
#
# --- **Richard Curtis** (2 films) ---
#     - About Time
#     - Love Actually
#
#
# --- **Quentin Tarantino** (2 films) ---
#     - Pulp Fiction
#     - Reservoir Dogs
#
#
# --- **Ridley Scott** (2 films) ---
#     - Blade Runner
#     - Seul Sur Mars
#
#
# --- **Steven Spielberg** (2 films) ---
#     - Munich
#     - The Post
#
#
# --- **David O. Russell** (2 films) ---
#     - Happiness Therapy
#     - Joy
#
#
# --- **Martin Scorsese** (8 films) ---
#     - After Hours
#     - Casino
#     - Gangs of New York
#     - GoodFellas
#     - Killers of the Flower Moon
#     - La Dernière Tentation du Christ
#     - The Departed
#     - The Irishman
#
#
# --- **Gus Van Sant** (2 films) ---
#     - Elephant
#     - Harvey Milk
#
#
# --- **Clint Eastwood** (3 films) ---
#     - American Sniper
#     - Juror 2
#     - Mystic river
#
#
# --- **Sergio Leone** (4 films) ---
#     - Et pour quelques dollars de plus
#     - Il Etait une fois dans l'Ouest
#     - Le bon la brute et le truand
#     - Once Upon a Time in America
#
#
# --- **Jonathan Glazer** (2 films) ---
#     - Birth
#     - The Zone Of Interest
#
#
# --- **Ron Howard** (2 films) ---
#     - A Beautiful Mind
#     - Eden
#
#
# --- **David Lynch** (3 films) ---
#     - Dune
#     - Mulholland Drive
#     - The Elephant Man
#
#
# --- **Xavier Dolan** (3 films) ---
#     - Juste la fin du monde
#     - Ma Vie Avec John F Donovan
#     - Mommy
#
#
# --- **Denis Villeneuve** (2 films) ---
#     - Enemy
#     - Prisoners
#
#
# --- **Paul Thomas Anderson** (3 films) ---
#     - Boogie Nights
#     - Licorice Pizza
#     - Punch Drunk Love
#
#
# --- **Steven Soderbergh** (2 films) ---
#     - Black Bag
#     - Erin Brockovich
#
#
# --- **Michael Mann** (2 films) ---
#     - Collateral
#     - The Last of the Mohicans
#
#
# --- **Francis Lawrence** (2 films) ---
#     - Constantine
#     - The Long Walk
#
#
# --- **Stanley Kubrick** (4 films) ---
#     - A Clockwork Orange
#     - Eyes Wide Shut
#     - Full Metal Jacket
#     - Les Sentiers De La Gloire
#
#
# --- **Tim Mielants** (2 films) ---
#     - Small Things Like These
#     - Steve
#
#
# --- **Sofia Coppola** (2 films) ---
#     - Priscilla
#     - The Virgin Suicides
#
#
# --- **Yorgos Lanthimos** (2 films) ---
#     - The Favourite
#     - The Lobster
#
#
# --- **Guillermo del Toro** (2 films) ---
#     - Frankenstein
#     - Nightmare Alley
#
#
# --- **Damien Chazelle** (2 films) ---
#     - First Man
#     - Whiplash
#
#
#
# ======================================================================
# 📋 RAW ANALYSIS DETAILS (50 first)
# ======================================================================
#                                         Original Name  \
# 0                             Citizen Kane (1941).mp4
# 1   Star Wars Episode V The Empire Strikes Back (1...
# 2                      La Vie d'Adèle (2013) x265.mp4
# 3                      House of the Dragon S02E05.mp4
# 4                     Nightcrawler (2014) x264 v2.mp4
# 5                          Game of Thrones S04E03.mp4
# 6                                  Ben-Hur (1959).mkv
# 7                       The Big Short (2015) x265.mp4
# 8                            The Machinist (2004).mp4
# 9                         Fantastic Mr Fox (2009).mp4
# 10                                The Pitt S01E07.mp4
# 11                              The Killer (2024).mp4
# 12                                     Lee (2023).mp4
# 13                            Perfect Blue (1998).mp4
# 14                              About Time (2013).mp4
# 15                            Pulp Fiction (1994).mp4
# 16                            Blade Runner (1982).mp4
# 17  Star Wars Episode VI Return Of The Jedi (1983)...
# 18                               Wednesday S01e04.mp4
# 19  Star Wars Episode I The Phantom Menace (1999).mp4
# 20                                  The Nice Guys.mp4
# 21                               127 Hours (2010).mp4
# 22                Triangle of Sadness (2022) x265.mp4
# 23                                The Post (2017).mp4
# 24                                 Amadeus (1984).mp4
# 25                            Good Fortune (2025).mp4
# 26                       Happiness Therapy (2012).mp4
# 27                                  Gifted (2017).mp4
# 28                                  Jackie (2016).mp4
# 29               The Princess And The Frog (2009).mp4
# 30                           Rien a foutre (2022).mp4
# 31                                American Beauty.mp4
# 32                                   The Prestige.mp4
# 33                                 Shooter (2007).mp4
# 34                                Aftersun (2022).mp4
# 35                         The Idea of You (2024).mp4
# 36                   Les Indestructibles 2 (2018).mp4
# 37                            Corpse Bride (2005).mp4
# 38                                          #02 Shows
# 39                                  Cars 3 (2017).mp4
# 40                             Vanilla Sky (2001).mp4
# 41               The Banshees of Inisherin (2022).mp4
# 42                                 The.Lighthouse.mp4
# 43         Star Wars Episode IV A New Hope (1977).mp4
# 44                           Seul Sur Mars (2015).mp4
# 45                L'Histoire de Souleymane (2024).mp4
# 46                                 Mad Max (1979).mp4
# 47    La Dernière Tentation du Christ (1988) x265.mp4
# 48                            I Am Nevenka (2024).mp4
# 49         The Perks of Being a Wallflower (2012).mp4
#
#                                   Cleaned Title  Year             Director  \
# 0                                  Citizen Kane  1941         Orson Welles
# 1   Star Wars Episode V The Empire Strikes Back  1980       Irvin Kershner
# 2                                La Vie d'Adèle  2013  Abdellatif Kechiche
# 3                           House of the Dragon     -            TV Series
# 4                                  Nightcrawler  2014           Dan Gilroy
# 5                               Game of Thrones     -            TV Series
# 6                                       Ben-Hur  1959        William Wyler
# 7                                 The Big Short  2015           Adam McKay
# 8                                 The Machinist  2004        Brad Anderson
# 9                              Fantastic Mr Fox  2009         Wes Anderson
# 10                                     The Pitt     -            TV Series
# 11                                   The Killer  2024             John Woo
# 12                                          Lee  2023          Ellen Kuras
# 13                                 Perfect Blue  1998          Satoshi Kon
# 14                                   About Time  2013       Richard Curtis
# 15                                 Pulp Fiction  1994    Quentin Tarantino
# 16                                 Blade Runner  1982         Ridley Scott
# 17      Star Wars Episode VI Return Of The Jedi  1983     Richard Marquand
# 18                                    Wednesday     -            TV Series
# 19       Star Wars Episode I The Phantom Menace  1999         George Lucas
# 20                                The Nice Guys     -          Shane Black
# 21                                    127 Hours  2010          Danny Boyle
# 22                          Triangle of Sadness  2022        Ruben Östlund
# 23                                     The Post  2017     Steven Spielberg
# 24                                      Amadeus  1984         Miloš Forman
# 25                                 Good Fortune  2025          Aziz Ansari
# 26                            Happiness Therapy  2012     David O. Russell
# 27                                       Gifted  2017            Marc Webb
# 28                                       Jackie  2016        Pablo Larraín
# 29                    The Princess And The Frog  2009         Ron Clements
# 30                                Rien a foutre  2022      Julie Lecoustre
# 31                              American Beauty     -           Sam Mendes
# 32                                 The Prestige     -    Christopher Nolan
# 33                                      Shooter  2007        Antoine Fuqua
# 34                                     Aftersun  2022      Charlotte Wells
# 35                              The Idea of You  2024    Michael Showalter
# 36                        Les Indestructibles 2  2018            Brad Bird
# 37                                 Corpse Bride  2005         Mike Johnson
# 38                                    #02 Shows     -            Not Found
# 39                                       Cars 3  2017            Brian Fee
# 40                                  Vanilla Sky  2001        Cameron Crowe
# 41                    The Banshees of Inisherin  2022      Martin McDonagh
# 42                               The Lighthouse     -        Robert Eggers
# 43              Star Wars Episode IV A New Hope  1977         George Lucas
# 44                                Seul Sur Mars  2015         Ridley Scott
# 45                     L'Histoire de Souleymane  2024        Boris Lojkine
# 46                                      Mad Max  1979        George Miller
# 47              La Dernière Tentation du Christ  1988      Martin Scorsese
# 48                                 I Am Nevenka  2024        Icíar Bollaín
# 49              The Perks of Being a Wallflower  2012      Stephen Chbosky
#
#                           Saga        Status
# 0                            -            OK
# 1         Star Wars Collection            OK
# 2                            -            OK
# 3                            -     TV Series
# 4                            -            OK
# 5                            -     TV Series
# 6                            -            OK
# 7                            -            OK
# 8                            -            OK
# 9                            -            OK
# 10                           -     TV Series
# 11                           -            OK
# 12                           -            OK
# 13                           -            OK
# 14                           -            OK
# 15                           -            OK
# 16     Blade Runner Collection            OK
# 17        Star Wars Collection            OK
# 18                           -     TV Series
# 19        Star Wars Collection            OK
# 20                           -            OK
# 21                           -            OK
# 22                           -            OK
# 23                           -            OK
# 24                           -            OK
# 25                           -            OK
# 26                           -            OK
# 27                           -            OK
# 28                           -            OK
# 29                           -            OK
# 30                           -            OK
# 31                           -            OK
# 32                           -            OK
# 33                           -            OK
# 34                           -            OK
# 35                           -            OK
# 36  The Incredibles Collection            OK
# 37                           -            OK
# 38                           -  Manual Check
# 39             Cars Collection            OK
# 40                           -            OK
# 41                           -            OK
# 42                           -            OK
# 43        Star Wars Collection            OK
# 44                           -            OK
# 45                           -            OK
# 46          Mad Max Collection            OK
# 47                           -            OK
# 48                           -            OK
# 49                           -            OK
